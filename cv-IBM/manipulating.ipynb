# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# figure size

# %%
baboon = cv2.imread("../emre/baboon.jpg")
plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(baboon, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# copy an image

# %%
A= baboon

# %%
id(A)==id(baboon) #  i think id is pointer in Python like in 
id(A)
# Out:
# 2642513754704

# %%
B = baboon.copy() 
id(B)==id(baboon)
# Out:
# False

# %%
baboon[:,:,] = 0 # baboon sıfırlandı

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(cv2.cvtColor(baboon, cv2.COLOR_BGR2RGB))
plt.title("baboon")
plt.subplot(122)
plt.imshow(cv2.cvtColor(A, cv2.COLOR_BGR2RGB))
plt.title("array A")
plt.subplot(232)
plt.title("array B")
plt.imshow(cv2.cvtColor(B, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# Flipping images

# %%
image = cv2.imread("../emre/kenanevren.jpg")
plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
width, height,C=image.shape
print('width, height,C',width, height,C)
# Out:
# width, height,C 627 1200 3

# %%
array_flip = np.array(image)

# %%
for i,row in enumerate(image):
        array_flip[width-1-i,:,:]=row

# %%
plt.figure(figsize=(5,5))
plt.imshow(cv2.cvtColor(array_flip, cv2.COLOR_BGR2RGB))
plt.show()
