# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
def olay_gerceklesti(event , x,y ,flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(bos_resim,(x,y), 50, (127,127,127),-1)
    elif event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(bos_resim,(x,y), 50, (50,50,50),-1)
    pass

cv2.namedWindow("ResimPenceresi")
cv2.setMouseCallback("ResimPenceresi", olay_gerceklesti)
bos_resim = np.zeros((1000,1000,3), dtype=np.uint8)

while True:
   cv2.imshow("ResimPenceresi", bos_resim)
   key = cv2.waitKey(10)
   if key == ord("q"):
       cv2.destroyAllWindows()
       break


# cv2.imshow("ResimPenceeresi", bos_resim)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
image  = plt.imread("baboon.jpg")
image1  = plt.imread("deneme.jpg")
image2 = plt.imread("kk.jpeg")
image3 = plt.imread("emre.jpg")
image4 = plt.imread("kenanevren.jpg", cv2.COLOR_BAYER_BG2GRAY)

# %%
sonuc2 = cv2.blur(image3, (3,3))
sonuc1 = cv2.medianBlur(image1,15)
sonuc3 = cv2.GaussianBlur(image2,(3,3),sigmaX=50)

f, eksen = plt.subplots(2,2)
eksen[0,0].imshow(sonuc1)
eksen[0,1].imshow(sonuc2)
eksen[1,1].imshow(sonuc3)

# %%
# ilresim = cv2.imread("kenanevren.jpg")
# kopyasi = ilresim.copy()
# matris = np.array([[0, -1, 0],
#                    [-1, 5, -1],
#                    [0, -1, 0]])
# for satir in ilresim.shape[1]:
#     for sutun in ilresim.shape[0]:
#         kopyasi[satir+1,sutun+1] = ilresim[]

# %%
# import cv2
# import numpy as 
# ilresim = cv2.imread("kenanevren.jpg")
# kopyasi = ilresim.copy()
# matris = np.array([[0, -1, 0],
#                    [-1, 5, -1],
#                    [0, -1, 0]])

# for satir in range(1, ilresim.shape[0]-1):
#     for sutun in range(1, ilresim.shape[1]-1):
#         kopyasi[satir, sutun] = 

# cv2.imshow("Orijinal Resim", ilresim)
# cv2.imshow("Dönüştürülmüş Resim", kopyasi)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
#   Cell In[16], line 11
#     kopyasi[satir, sutun] =
#                             ^
# SyntaxError: invalid syntax

# %%
ilresim = cv2.imread("deneme.jpg")
kopyasi = ilresim.copy()
matris = np.array([[0, -1, 0],
                   [-1, 5, -1],
                   [0, -1, 0]])

for satir in range(1, ilresim.shape[0]-1):
    for sutun in range(1, ilresim.shape[1]-1):
        deger = np.sum(np.multiply(kopyasi[satir-1:satir+2, sutun-1:sutun+2], matris))
        kopyasi[satir, sutun] = deger

cv2.imshow("ilhali", ilresim)
cv2.imshow("dönüsmüs", kopyasi)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
resim = cv2.imread("emre.jpg")

matris = np.array([[0, -1, 0],
                   [-1, 5, -1],
                   [0, -1, 0]])
resim = cv2.filter2D(resim,-1,matris)

cv2.imwrite("emre.jpg",resim)
# Out:
# True

# %%
pencere = plt.figure(figsize=(10,10)) #9 w, e h inch
pencere.add_subplot(2,2,1)
plt.imshow(image)
pencere.add_subplot(2,2,2)
plt.imshow(image1)
pencere.add_subplot(2,2,3)
plt.imshow(image2)
pencere.add_subplot(2,2,4)
plt.imshow(image4)

# %%
f, eksen = plt.subplots(2,2)
eksen[0,0].imshow(image)
eksen[0,1].imshow(image1)
eksen[1,0].imshow(image4)
eksen[1,1].imshow(image3)

# %% [markdown]
# tresh_binary
# tresh_binary_inv
# tresh_trunc
# tresh_tozero
# tresh_tozero_inv
# tresh_otsu // bazen
# tresh_Triangle
# (aynalama nedir)
