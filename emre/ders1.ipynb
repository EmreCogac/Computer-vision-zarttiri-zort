# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\emrem\OneDrive\Masaüstü\Computer vision\emre\ders1.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/emrem/OneDrive/Masa%C3%BCst%C3%BC/Computer%20vision/emre/ders1.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import cv2
# ----> <a href='vscode-notebook-cell:/c%3A/Users/emrem/OneDrive/Masa%C3%BCst%C3%BC/Computer%20vision/emre/ders1.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/emrem/OneDrive/Masa%C3%BCst%C3%BC/Computer%20vision/emre/ders1.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
#
# File c:\Users\emrem\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:56
#      54 from cycler import cycler
#      55 import matplotlib
# ---> 56 import matplotlib.colorbar
#      57 import matplotlib.image
# ...

# %%
# image = cv2.imread("emre.jpg", cv2.IMREAD_COLOR)
# image2 = cv2.imread("emre.jpg",cv2.IMREAD_COLOR)

# resizedImage = cv2.resize(image,(400,1000))
# arrayEmre = np.array(image)

# arrayEmre.shape

# resizedImage.shape
# grayEmre = cv2.cvtColor(resizedImage , cv2.COLOR_BGR2GRAY)
# cv2.imshow("deneme",grayEmre)
# cv2.waitKey(0)
# cv2.destroyAllWindows() #açılmış tüm imagelari kapar

# %%
image1 = cv2.imread("baboon.jpg", cv2.IMREAD_COLOR)
resim = plt.imread("baboon.jpg")

image2 = cv2.rectangle(image1,(int(image1.shape[1]/2)-25,int(image1.shape[1]/2)-25),(int(image1.shape[0]/2)+25,int(image1.shape[0]/2)+25),(0,0,0),5)

# image2[int(image2.shape[0]/2)-25:int(image2.shape[0]/2)+25,int(image2.shape[1]/2)-25:int(image2.shape[1]/2)+25,:] = [0,0,0]




cv2.imshow("deneme", image2)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\emrem\OneDrive\Masaüstü\Computer vision\emre\ders1.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/emrem/OneDrive/Masa%C3%BCst%C3%BC/Computer%20vision/emre/ders1.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> image1 = cv2.imread("baboon.jpg", cv2.IMREAD_COLOR)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/emrem/OneDrive/Masa%C3%BCst%C3%BC/Computer%20vision/emre/ders1.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> resim = plt.imread("baboon.jpg")
#       <a href='vscode-notebook-cell:/c%3A/Users/emrem/OneDrive/Masa%C3%BCst%C3%BC/Computer%20vision/emre/ders1.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> image2 = cv2.rectangle(image1,(int(image1.shape[1]/2)-25,int(image1.shape[1]/2)-25),(int(image1.shape[0]/2)+25,int(image1.shape[0]/2)+25),(0,0,0),5)
# ...

# %%
bas_resim = np.zeros(shape=(512,512,3))
cv2.rectangle(bas_resim,(400,200),(200,0),(0,0,255),10) # nereden başlarsam sağa doğoğru yazmam gerekir mesela color=() versirsem pt1 vs çizmem gerekiyor 
plt.imshow(bas_resim)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
bas_resim = np.zeros(shape=(512,512,3))

# %%
cv2.circle(bas_resim,(300,100),50,(255,0,255),-1)
plt.imshow(bas_resim)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
cv2.line(bas_resim,(0,0),(512,512),(255,255,255),12)
# cv2.putText(bas_resim,"selam",(10,500))
plt.imshow(bas_resim)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
