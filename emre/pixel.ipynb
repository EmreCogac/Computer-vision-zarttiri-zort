# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = plt.imread("emre.jpg")

# %%
img[0][0][1]
# Out:
# 250

# %%
img
# Out:
# array([[[250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250]],
#
#        [[250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250]],
#
#        [[250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250]],
#
#        ...,
#
#        [[114, 120, 132],
#         [ 61,  67,  79],
#         [ 48,  52,  63],
#         ...,
#         [109, 113, 151],
#         [103, 105, 143],
#         [  0,   0,  34]],
#
#        [[ 89,  97, 108],
#         [105, 113, 124],
#         [ 72,  79,  89],
#         ...,
#         [ 77,  79, 118],
#         [ 44,  42,  81],
#         [  0,   0,  35]],
#
#        [[104, 112, 123],
#         [ 45,  53,  64],
#         [ 86,  93, 103],
# ...

# %%
# for rows in img :
#     img[rows] *15/10
#     for colm in rows:
#         for pixel in colm:

# %%
img = np.asarray(img)

# %%
image = img *2
newImage = np.clip(image, a_min = 0, a_max = 255)

# %%
newImage
# Out:
# array([[[244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244],
#         ...,
#         [244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244]],
#
#        [[244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244],
#         ...,
#         [244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244]],
#
#        [[244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244],
#         ...,
#         [244, 244, 244],
#         [244, 244, 244],
#         [244, 244, 244]],
#
#        ...,
#
#        [[228, 240,   8],
#         [122, 134, 158],
#         [ 96, 104, 126],
#         ...,
#         [218, 226,  46],
#         [206, 210,  30],
#         [  0,   0,  68]],
#
#        [[178, 194, 216],
#         [210, 226, 248],
#         [144, 158, 178],
#         ...,
#         [154, 158, 236],
#         [ 88,  84, 162],
#         [  0,   0,  70]],
#
#        [[208, 224, 246],
#         [ 90, 106, 128],
#         [172, 186, 206],
# ...

# %%
plt.imshow(newImage)
