# %%
from PIL import Image
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = Image.open("emre.jpg")
imgkk = Image.open("kk.jpeg")

img1 = img.resize((100,100))
img2 = imgkk.resize((100,100))

# %%
img1.save("deneme.png")

# %%
kk = plt.imread("kk.jpeg")

# %%
kenanevren = plt.imread("emre.jpg")

# %%
kYukseklik, kGenislik, kKanal=kk.shape

# %%
bYukseklik, bGenislik, bKanal =kenanevren.shape

# %%
roialan = kenanevren[bYukseklik-kYukseklik:,bGenislik -kGenislik:].copy()

# %%
roialan = cv2.addWeighted(roialan,0.5,kk,0.5,10)
kenanevren[bYukseklik - kYukseklik: ,0:kGenislik]
# Out:
# array([[[179, 171, 168],
#         [ 99,  91,  88],
#         [131, 123, 121],
#         ...,
#         [246, 247, 242],
#         [236, 237, 232],
#         [255, 255, 251]],
#
#        [[ 72,  66,  66],
#         [231, 225, 225],
#         [183, 177, 179],
#         ...,
#         [253, 252, 248],
#         [250, 249, 245],
#         [235, 236, 231]],
#
#        [[144, 138, 140],
#         [106, 100, 102],
#         [134, 128, 132],
#         ...,
#         [253, 249, 246],
#         [255, 254, 250],
#         [247, 246, 242]],
#
#        ...,
#
#        [[114, 120, 132],
#         [ 61,  67,  79],
#         [ 48,  52,  63],
#         ...,
#         [ 48,  46,  67],
#         [ 93,  92, 110],
#         [ 16,  14,  28]],
#
#        [[ 89,  97, 108],
#         [105, 113, 124],
#         [ 72,  79,  89],
#         ...,
#         [ 48,  49,  70],
#         [ 65,  64,  82],
#         [ 41,  39,  53]],
#
#        [[104, 112, 123],
#         [ 45,  53,  64],
#         [ 86,  93, 103],
# ...

# %%
plt.imshow(roialan)
