# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = plt.imread("emre.jpg")

# %%
img[0][0][1]
# Out:
# 250

# %%
img
# Out:
# array([[[250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250]],
#
#        [[250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250]],
#
#        [[250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250],
#         ...,
#         [250, 250, 250],
#         [250, 250, 250],
#         [250, 250, 250]],
#
#        ...,
#
#        [[ 92,  96, 108],
#         [ 80,  84,  96],
#         [ 74,  78,  89],
#         ...,
#         [ 74,  79, 119],
#         [ 70,  73, 114],
#         [ 38,  40,  81]],
#
#        [[ 88,  94, 106],
#         [ 86,  92, 104],
#         [ 78,  85,  95],
#         ...,
#         [ 64,  65, 109],
#         [ 57,  56,  98],
#         [ 38,  37,  79]],
#
#        [[ 87,  93, 105],
#         [ 77,  83,  95],
#         [ 80,  87,  97],
# ...

# %%
# for rows in img :
#     img[rows] *15/10
#     for colm in rows:
#         for pixel in colm:

# %%
img = np.asarray(img)

# %%
image = img *200
newImage = np.clip(image, a_min = 0, a_max = 255)

# %%
newImage
# Out:
# array([[[212, 212, 212],
#         [212, 212, 212],
#         [212, 212, 212],
#         ...,
#         [212, 212, 212],
#         [212, 212, 212],
#         [212, 212, 212]],
#
#        [[212, 212, 212],
#         [212, 212, 212],
#         [212, 212, 212],
#         ...,
#         [212, 212, 212],
#         [212, 212, 212],
#         [212, 212, 212]],
#
#        [[212, 212, 212],
#         [212, 212, 212],
#         [212, 212, 212],
#         ...,
#         [212, 212, 212],
#         [212, 212, 212],
#         [212, 212, 212]],
#
#        ...,
#
#        [[248, 192,  24],
#         [160, 104, 192],
#         [116,  60,  98],
#         ...,
#         [116, 110,  62],
#         [172,  66,  68],
#         [108, 208, 210]],
#
#        [[ 48,  92, 180],
#         [204, 248,  80],
#         [ 60, 154, 142],
#         ...,
#         [128, 178,  74],
#         [ 34, 240,  36],
#         [108,  58, 110]],
#
#        [[254,  42, 130],
#         [ 10,  54, 142],
#         [160, 254, 242],
# ...

# %%
plt.imshow(newImage)
